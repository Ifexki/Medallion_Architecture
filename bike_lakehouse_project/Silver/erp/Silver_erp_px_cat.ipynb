# %% [markdown]
# ### READ DATA FROM BRONZE

# %%
df = spark.table('workspace.bronze_schema.px_cat_delta')
df.display()

# %%
df.write.mode('overwrite').saveAsTable('workspace.silver_schema.px_cat_delta')

# %%
#df = spark.table('workspace.bronze_schema.loc_a101_delta')
df.display()

# %%
df = spark.table('workspace.bronze_schema.cust_az_delta')
df.display()
