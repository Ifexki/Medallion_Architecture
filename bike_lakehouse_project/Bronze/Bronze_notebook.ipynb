# %% [markdown]
# ###Read Data From Bronze Volume (Sales_info)

# %%
df = spark.read.format("csv").option('inferSchema',True).option('header',True).load('/Volumes/workspace/bronze_schema/bronze_volume/crm/sales_details.csv')
df.display()

# %% [markdown]
# ### Write to Bronze Layer(Sales_info)

# %%
df.write.mode('overwrite').saveAsTable('bronze_schema.sales_info_delta_1')

# %%
# %sql
SELECT * FROM bronze_schema.sales_info_delta_1

# %%
# %sql
Select * From workspace.bronze_schema.sales_info_delta_1

# %%
# %sql
DROP TABLE IF EXISTS workspace.bronze_schema.sales_info_delta

# %% [markdown]
# ### Read Data from Bronze Volume (Prd_info)

# %%
df_prod_info= spark.read.format("csv").option('inferSchema',True).option('header',True).load('/Volumes/workspace/bronze_schema/bronze_volume/crm/prd_info.csv')
df_prod_info.display()

# %% [markdown]
# ###Write to Bronze Layer (Prd_info)

# %%
df_prod_info.write.mode('overwrite').saveAsTable('bronze_schema.prod_info_delta')

# %% [markdown]
# ###Read and Write to Bronze Layer (Cust_info)

# %%
df_cust_info= spark.read.format("csv").option('inferSchema',True).option('header',True).load('/Volumes/workspace/bronze_schema/bronze_volume/crm/cust_info.csv')
df_cust_info.display()



df_cust_info.write.mode('overwrite').saveAsTable('bronze_schema.cust_info_delta')

# %% [markdown]
# ### IMPORT FROM ERP

# %% [markdown]
# ### READ AND WRITE PX_CAT_G1V TO BRONZE LAYER

# %%
df_px_cat= spark.read.format("csv").option('inferSchema',True).option('header',True).load('/Volumes/workspace/bronze_schema/bronze_volume/erp/PX_CAT_G1V2.csv')
df_px_cat.display()



df_px_cat.write.mode('overwrite').saveAsTable('bronze_schema.px_cat_delta')

# %% [markdown]
# ### READ AND WRITE LOC_A101 TO BRONZE LAYER

# %%
df_loc_a101 = spark.read.format("csv").option('inferSchema',True).option('header',True).load('/Volumes/workspace/bronze_schema/bronze_volume/erp/LOC_A101.csv')
df_loc_a101.display()



df_loc_a101.write.mode('overwrite').saveAsTable('bronze_schema.loc_a101_delta')

# %% [markdown]
# ###  READ AND WRITE CUST_AZ12 TO BRONZE LAYER

# %%
df_cust_az12 = spark.read.format("csv").option('inferSchema',True).option('header',True).load('/Volumes/workspace/bronze_schema/bronze_volume/erp/CUST_AZ12.csv')
df_cust_az12.display()



df_cust_az12.write.mode('overwrite').saveAsTable('bronze_schema.cust_az_delta')

# %%
- Create a dictionary to store file paths and table names
- Loop through the dictionary to ingest all files
